# %%
# Imports
import pandas as pd
import requests as rq
import json

# %%
# Création du DataFrame
dataframe = pd.DataFrame(columns=['Adresse', 'Commune', 'Code_postal','Coord_X', 'Coord_Y'])

# %%
# Requete à l'API de Velov 
response = rq.get("https://download.data.grandlyon.com/ws/grandlyon/pvo_patrimoine_voirie.pvostationvelov/all.json?maxfeatures=-1&start=1")
data = response.json()
for rc in data['values']:
    dataframe.loc[len(dataframe.index)] = [rc['adresse1'],rc['commune'],rc['code_insee'],rc['lat'],rc['lon']]

dataframe_communes_ciblees = dataframe.query("Commune == 'Lyon 1er Arrondissement' | Commune == 'Lyon 2e Arrondissement' | Commune == 'Lyon 3e Arrondissement'| Commune == 'Lyon 4e Arrondissement'| Commune == 'Lyon 5e Arrondissement'| Commune == 'Lyon 6e Arrondissement'| Commune == 'Lyon 7e Arrondissement'| Commune == 'Lyon 8e Arrondissement'| Commune == 'Lyon 9e Arrondissement'| Commune == 'Bron'| Commune == 'Villeurbanne'")

# %%
dataframe_communes_ciblees
# Out:
#                           Adresse                  Commune Code_postal  \
# 0       Face au 140, Rue Bataille   Lyon 8e Arrondissement       69388
# 1            29, Rue de la Bourse  Lyon 1er Arrondissement       69381
# 2    Face 31, Rue Albert Chalinel   Lyon 9e Arrondissement       69389
# 3      Face 56, Quai Pierre Scize   Lyon 5e Arrondissement       69385
# 4            Place du Port Mouton   Lyon 9e Arrondissement       69389
# ..                            ...                      ...         ...
# 426  Face 16, Quai Claude Bernard   Lyon 7e Arrondissement       69387
# 427    80, Quai Charles de Gaulle   Lyon 6e Arrondissement       69386
# 428          Allée Achille Lignon   Lyon 6e Arrondissement       69386
# 429   Face 8, Quai Claude Bernard   Lyon 7e Arrondissement       69387
# 430            209, Rue Paul Bert   Lyon 3e Arrondissement       69383
#
#        Coord_X   Coord_Y
# 0    45.736268  4.879737
# 1    45.765811  4.836896
# 2    45.801120  4.825273
# 3    45.766580  4.820230
# 4    45.773820  4.809560
# ..         ...       ...
# 426  45.751101  4.836144
# 427  45.784711  4.851930
# 428  45.783882  4.852140
# 429  45.753611  4.838221
# 430  45.757084  4.853477
#
# [389 rows x 5 columns]

# %%
# Export en csv
dataframe.to_csv('velov.csv',sep=";")
